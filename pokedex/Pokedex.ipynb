# %%
import os
import random
from keras.preprocessing import image
import keras
from keras.layers import *
from keras.models import Sequential
import numpy as np
import pandas as pd
import shutil

# %%
im = image.load_img('c:/Users/nishant/pokedex/Train/Meowth/02ccc0f3904343ffb4b64e369e385068.jpg')

# %%
input_arr = image.img_to_array(im)

# %%
input_arr.shape
# Out:
# (342, 245, 3)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500 at 0x1B4C0F96310>

# %%
folders = os.listdir('c:/Users/nishant/pokedex/Train')

# %%
classes = ['Aerodactyl','Bulbasaur','Charmander','Dratini','Fearow','Meowth','Pikachu','Psyduck','Spearow','Squirtle']

# %%
for c in classes:
    p = os.path.join('c:/Users/nishant/pokedex/validation',c)
    print(p)
    os.mkdir(p)
# Out:
# c:/Users/nishant/pokedex/validation\Aerodactyl
# c:/Users/nishant/pokedex/validation\Bulbasaur
# c:/Users/nishant/pokedex/validation\Charmander
# c:/Users/nishant/pokedex/validation\Dratini
# c:/Users/nishant/pokedex/validation\Fearow
# c:/Users/nishant/pokedex/validation\Meowth
# c:/Users/nishant/pokedex/validation\Pikachu
# c:/Users/nishant/pokedex/validation\Psyduck
# c:/Users/nishant/pokedex/validation\Spearow
# c:/Users/nishant/pokedex/validation\Squirtle

# %%
        
split = 0.9
for f in os.listdir('c:/Users/nishant/pokedex/Train'):
    path = 'c:/Users/nishant/pokedex/Train/'+f
    imgs = os.listdir(path)
    
    split_size  = int(split*len(imgs))
    files_to_move = imgs[split_size:]
    print(len(files_to_move))
    
    for img_f in files_to_move:
        src = os.path.join(path,img_f)
        dest = os.path.join('c:/Users/nishant/pokedex/validation/'+f,img_f)
        shutil.move(src,dest)
        print(src)
        print(dest)
# Out:
# 8
# c:/Users/nishant/pokedex/Train/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-41.jpg
# c:/Users/nishant/pokedex/validation/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-41.jpg
# c:/Users/nishant/pokedex/Train/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-42.jpg
# c:/Users/nishant/pokedex/validation/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-42.jpg
# c:/Users/nishant/pokedex/Train/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-5.jpg
# c:/Users/nishant/pokedex/validation/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-5.jpg
# c:/Users/nishant/pokedex/Train/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-6.jpg
# c:/Users/nishant/pokedex/validation/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-6.jpg
# c:/Users/nishant/pokedex/Train/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-8.jpg
# c:/Users/nishant/pokedex/validation/Aerodactyl\ef7f7eeaa897478bbe1df7b0bb0522cb-8.jpg
# c:/Users/nishant/pokedex/Train/Aerodactyl\f403dcd3136643e4b43c7d01e14494bc.jpg
# ...

# %%
label_dict = {
    "Aerodactyl" : 0 ,  
    "Bulbasaur":1  ,  
    "Charmander":2 , 
    "Dratini":3,  
    "Fearow":4 ,  
    "Meowth":5 ,  
    "Pikachu":6 ,  
    "Psyduck":7  ,  
    "Spearow":8 ,  
    "Squirtle":9   
}
image_data = []
labels = []

# %%
for file in folders:
    print(file)
    path = os.path.join('c:/Users/nishant/pokedex/Train',file)
    count = 0
    for images in os.listdir(path):
        try:
            im = image.load_img(os.path.join(path,images),target_size=((224,224)))
            im = image.img_to_array(im)
            image_data.append(im)
            labels.append(label_dict[file])
        except:
            print(f'{file} {images} has error')
# Out:
# Aerodactyl
# Bulbasaur
# Charmander
# C:\Users\nishant\anaconda3\lib\site-packages\PIL\Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Dratini
# Fearow
# Fearow 2c8d5221e92444f2b9477350e405bc54.svg has error
# Fearow 8f2d7986ab76482fb76cac6a91b66de4.svg has error
# Meowth
# Pikachu
# Psyduck
# Spearow
# Squirtle

# %%
print(len(image_data))
print(len(labels))
# Out:
# 1645
# 1645

# %%
combined = list(zip(image_data,labels))
random.shuffle(combined)
image_data[:],labels[:] = zip(*combined)

# %%
x_train = np.array(image_data)
y_train = np.array(labels)
print(x_train.shape)
print(y_train.shape)
# Out:
# (1645, 224, 224, 3)
# (1645,)

# %%
y_train = keras.utils.to_categorical(y_train)
print(y_train.shape)
# Out:
# (1645, 10)

# %%
train_datagen = image.ImageDataGenerator(
    rescale=1./255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
val_datagen = image.ImageDataGenerator(
           rescale = 1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
        'c:/Users/nishant/pokedex/Train',
        target_size=(224, 224),
        batch_size=32,
        class_mode ='categorical',
        shuffle=True
    
)
# Out:
# Found 1474 images belonging to 10 classes.

# %%
validation_generator = val_datagen.flow_from_directory(
        'c:/Users/nishant/pokedex/validation',
        target_size=(224,224),
        batch_size=32,
        class_mode ='categorical',
        shuffle=True
        )
# Out:
# Found 168 images belonging to 10 classes.

# %%
test_folder = os.listdir('c:/Users/nishant/pokedex/Test/images')

# %%
df = pd.read_csv('c:/Users/nishant/pokedex/Test/sample_submission.csv')

# %%
y_test_name = list(df['Name'])

# %%
y_test = []
for im in y_test_name:
    path = 'c:/Users/nishant/pokedex/Test/images'
    im = image.load_img(os.path.join(path,im),target_size=((224,224)))
    im = image.img_to_array(im)
    y_test.append(im)

# %%
y_test = np.array(y_test)
y_test_name = np.array(y_test_name)
print(y_test.shape,y_test_name.shape)
# Out:
# (187, 224, 224, 3) (187,)

# %%
print(y_test.shape)
print(y_test_name.shape)
# Out:
# (187, 224, 224, 3)
# (187,)

# %% [markdown]
# # Implementing AlexNet

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(224,224,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 54, 54, 96)        34944
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 54, 54, 96)        384
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 96)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 26, 26, 256)       614656
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 26, 26, 256)       1024
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 12, 12, 384)       885120
# ...

# %%
model.fit(x_train,y_train,epochs=2,validation_split=0.2)
# Out:
# Epoch 1/2
# 83/83 [==============================] - 182s 2s/step - loss: 1.6807 - accuracy: 0.4054 - val_loss: 1.7128 - val_accuracy: 0.3967
# Epoch 2/2
# 83/83 [==============================] - 167s 2s/step - loss: 1.5950 - accuracy: 0.4267 - val_loss: 1.5848 - val_accuracy: 0.4179

# %%
y_pred = model_new.predict(y_test)

# %%
y_pred = model_new.predict(y_test)
y_pred = y_pred.argmax(axis=1)

# %%
submission = pd.DataFrame(y_test_name,columns=['Name'])
pred = pd.DataFrame(y_pred,columns=['Class'])

# %%
submission = pd.concat([submission,pred],axis=1)

# %%
submission.to_csv('submission.csv',index=False)

# %% [markdown]
# # Using Transfer Learning

# %%
from keras.applications import MobileNetV2
from keras.models import Model
from keras.optimizers import Adam

# %%
model = MobileNetV2(include_top=False,weights="imagenet",input_shape=(224,224,3))

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
av1 = GlobalAveragePooling2D()(model.output)
fc1 = Dense(256,activation='relu')(av1)
d1 = Dropout(0.5)(fc1)
fc2 = Dense(10,activation='softmax')(d1)

model_new = Model(inputs=model.input,outputs=fc2)

# %%
model_new.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
model_new.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
for i in range(150):
    model_new.layers[i].trainable=False

# %%
model_new.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
hist  = model_new.fit_generator(train_generator,
        steps_per_epoch=32,
        epochs=30,
        validation_data=validation_generator
        )
# Out:
# C:\Users\nishant\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# C:\Users\nishant\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\nishant\anaconda3\lib\site-packages\keras_preprocessing\image\image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/30
# ...

# %%
df = pd.read_csv('c:/Users/nishant/pokedex/Test/sample_submission.csv')
y_test_name = list(df['Name'])

# %%
y_test = []
for im in y_test_name:
    path = 'c:/Users/nishant/pokedex/Test/images'
    im = image.load_img(os.path.join(path,im),target_size=((224,224)))
    im = image.img_to_array(im)
    y_test.append(im/255.0)

# %%
test_datagen = image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        'c:/Users/nishant/pokedex/Test',
        classes=['images'],
         target_size=(224, 224),
        class_mode=None,  # only data, no labels
        shuffle=False
        )
# Out:
# Found 187 images belonging to 1 classes.

# %%
pred = model_new.predict_generator(test_generator)

# %%
y_test_name = test_generator.filenames

# %%
pred = pred.argmax(axis=1)

# %%
filenames_to_cls = dict(zip(test_generator.filenames, pred))

# %%
df['class']  = filenames_to_cls(df
# Out:
#              Name  Class
# 0     test_32.jpg      0
# 1    test_147.jpg      0
# 2    test_171.jpg      0
# 3    test_114.jpg      0
# 4    test_162.jpg      0
# ..            ...    ...
# 182  test_150.jpg      0
# 183   test_72.jpg      0
# 184   test_95.jpg      0
# 185   test_88.jpg      0
# 186  test_110.jpg      0
#
# [187 rows x 2 columns]

# %%
'images\\test_14.jpg'

# %%
for i in range(len(df)):
    df.iloc[i,1]  = df.iloc[i,]
# Out:
# 'test_171.jpg'
