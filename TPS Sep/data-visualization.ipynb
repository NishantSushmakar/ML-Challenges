# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
sns.set_style("darkgrid")

# %%
df = pd.read_csv('c:/users/nishant/kaggle/input/tabular-playground-series-sep-2021/train.csv')

# %%
df.shape
# Out:
# (957919, 120)

# %%
df.sample(10)
# Out:
#             id        f1        f2        f3        f4       f5       f6  \
# 665994  665994  0.060963  0.489520    402.46  0.140360  0.41804 -1.50280
# 335659  335659  0.149900  0.318530  13474.00  0.128940  0.32052 -0.18362
# 526316  526316  0.156600  0.443700   3316.00  0.019462  0.29982 -0.78159
# 343116  343116  0.101090  0.497320    546.00       NaN  0.25919 -0.48585
# 489123  489123  0.089209  0.318880   1352.10  0.016091  0.44849  3.51250
# 676562  676562  0.101520  0.364860   -138.87  0.303890  0.16171  1.46220
# 673166  673166  0.062959  0.290440  18116.00  0.038767  0.30610 -1.46180
# 802174  802174  0.089668  0.475900    706.54  0.127730  0.46065  0.78047
# 43863    43863  0.031447  0.272620   1290.50  0.040973  0.35848 -1.39440
# 344987  344987  0.104220 -0.000289  15682.00  0.001696  0.19365  2.71660
#
#              f7        f8            f9  ...     f110    f111      f112  \
# 665994  1210.50  234730.0  1.005000e+14  ...  -7.8287  1.8149   3.31260
# ...

# %% [markdown]
# **Bar Plot for Claims**

# %%
df['claim'].value_counts().plot(kind='bar',color='red')
print(df['claim'].value_counts())
plt.show()
# Out:
# 0    480404
# 1    477515
# Name: claim, dtype: int64

# %% [markdown]
#  **Information from this plot :**
# * The Target is not imbalanced so we can use simple cross validation only.

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id       0.000000
# f1       1.591679
# f2       1.585729
# f3       1.617151
# f4       1.624354
#            ...
# f115     1.624250
# f116     1.627382
# f117     1.608382
# f118     1.588026
# claim    0.000000
# Length: 120, dtype: float64

# %%
max((df.isnull().sum()/len(df))*100)
# Out:
# 1.6366728293310813

# %%
sum(df.isnull().sum()>0)
# Out:
# 118

# %% [markdown]
# * All the features have null values almost of about 1%.
# * So the Null values will be filled with FFill

# %%
x = df.drop(columns=['id','claim']).columns

# %%
df = df.ffill(axis = 0)

# %%
scaler = MinMaxScaler()
df[x] = scaler.fit_transform(df[x])

# %%
df.head()
# Out:
#    id        f1        f2        f3        f4        f5        f6        f7  \
# 0   0  0.457457  0.043413  0.191647  0.070959  0.527183  0.105864  0.063687
# 1   1  0.443849  0.592256  0.433849  0.255789  0.830794  0.498215  0.344463
# 2   2  0.580343  0.022422  0.210943  0.252679  0.830402  0.540336  0.446403
# 3   3  0.534915  0.048887  0.208346  0.076533  0.937195  0.845347  0.059686
# 4   4  0.470978  0.970095  0.190185  0.271060  0.626428  0.516054  0.489029
#
#          f8        f9  ...      f110      f111      f112      f113      f114  \
# 0  0.102258  0.134102  ...  0.871211  0.343019  0.120557  0.261928  0.142026
# 1  0.077000  0.434246  ...  0.456876  0.907318  0.114198  0.413351  0.136327
# 2  0.200918  0.100675  ...  0.931311  0.216179  0.113851  0.467008  0.209030
# 3  0.148869  0.106339  ...  0.660647  0.417911  0.116023  0.137909  0.142970
# 4  0.048970  0.264354  ...  0.858063  0.292096  0.117449  0.351838  0.141167
#
# ...

# %%
plt.figure(figsize=(20,10))
df[x].var().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Some feature have very low variance they are nearly equal to zero

# %% [markdown]
# ## Questions
# * Is the data Linear or not
# * Outliers for each column
# * Distribution followed by each column

# %%
best_col  = df[x].var()>0.1
best_col = list(best_col[best_col==True].index)

# %%
best_col.append('claim')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=df['f40'],y=df['f42'],hue=df['claim'])
plt.show()

# %%
best_col
# Out:
# ['f29', 'f40', 'f42', 'f65', 'f70', 'f75', 'claim']

# %%
for col in x:
    sns.boxplot(df[col])
    plt.show()
# Out:
# C:\Users\nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for col in x:
    sns.distplot(df[col])
    plt.show()
# Out:
# C:\Users\nishant\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nishant\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
